# %%
#KAUN BANEGA CROREPATI

import random
import time

print("\n💰💰💰  WELCOME TO KAUN BANEGA CROREPATI  💰💰💰\n")

Questions  = [
    ["1. What is the correct file extension for Python files?",
     "a. .pt", "b. .py", "c. .pyt", "d. .ptn", 2],

    ["2. Which keyword is used to create a function in Python?",
     "a. func", "b. define", "c. def", "d. function", 3],

    ["3. What is the output of print(2 + 3 * 5)?",
     "a. 25", "b. 17", "c. 10", "d. 30", 2],

    ["4. Which of the following is a valid variable name in Python?",
     "a. 2name", "b. my-name", "c. my_name", "d. my name", 3],

    ["5. Which data type is used to store True or False values?",
     "a. string", "b. int", "c. bool", "d. float", 3],

    ["6. What will be the output of print(len('Python'))?",
     "a. 5", "b. 6", "c. 7", "d. 8", 2],

    ["7. Which function is used to get input from the user in Python?",
     "a. input()", "b. scan()", "c. get()", "d. read()", 1],

    ["8. Which operator is used for exponentiation in Python?",
     "a. ^", "b. **", "c. //", "d. %%", 2],

    ["9. How do you write a comment in Python?",
     "a. // comment", "b. <!-- comment -->", "c. # comment", "d. /* comment */", 3],

    ["10. What is the output of print(type(10))?",
     "a. <class 'float'>", "b. <class 'string'>", "c. <class 'int'>", "d. <class 'bool'>", 3],

    ["11. Which collection type is ordered and changeable in Python?",
     "a. Set", "b. Tuple", "c. Dictionary", "d. List", 4],

    ["12. What is the output of print('Hello' + 'World')?",
     "a. Hello World", "b. HelloWorld", "c. Error", "d. Hello+World", 2],

    ["13. Which keyword is used to start a loop in Python?",
     "a. for", "b. loop", "c. iterate", "d. repeat", 1],

    ["14. What does the 'break' statement do in a loop?",
     "a. Skips the current iteration", "b. Stops the loop completely", "c. Restarts the loop", "d. Pauses the loop", 2],

    ["15. Which function is used to display output in Python?",
     "a. display()", "b. echo()", "c. print()", "d. show()", 3],
]

Levels = [1000,2000,3000,5000, 10000,20000, 400000, 800000, 160000, 320000, 640000, 1250000, 2500000, 50000000, 10000000 ]

Money = 0

lifelines = {"50-50": True, "Ask the Audience": True, "Skip Question": True}

for i in range(0,len(Questions)):

  question = Questions[i]

  print(f"\nQuestion for Rs. {Levels[i]}:")

  print(question[0])
  print(question[1])
  print(question[2])
  print(question[3])
  print(question[4])

  # Offer lifeline option
  print("\nAvailable Lifelines:", [key for key, val in lifelines.items() if val])
  use_life = input("\nDo you want to use a lifeline? (yes/no): ").lower()

  if use_life == "yes":
        print("\nWhich lifeline do you want to use?")
        choice = input("1. 50-50\n2. Ask the Audience\n3. Skip Question\nEnter choice: ")

        # 50-50 Lifeline
        if choice == "1" and lifelines["50-50"]:
            lifelines["50-50"] = False
            correct = question[-1]
            options = [1, 2, 3, 4]
            options.remove(correct)
            remove = random.sample(options, 2)
            print("\nRemaining options are:")
            for j in range(1, 5):
                if j not in remove:
                    print(question[j])
        elif choice == "2" and lifelines["Ask the Audience"]:
            lifelines["Ask the Audience"] = False
            print("\n📊 Audience Poll Results:")
            time.sleep(1)
            correct = question[-1]
            for j in range(1, 5):
                if j == correct:
                    print(f"{question[j]} : {random.randint(60, 80)}%")
                else:
                    print(f"{question[j]} : {random.randint(5, 20)}%")
        elif choice == "3" and lifelines["Skip Question"]:
            lifelines["Skip Question"] = False
            print("\nYou chose to skip this question! Moving to the next one...")
            continue
        else:
            print("\n❌ Lifeline not available or invalid choice!")


  option =(int(input("\nChose Your Option from the above options i.e from option (a-d) in number format (1-4)   : \n")))


  if(option == question[-1] ):

    print(f"\nYAY This is the correct option, You have Won Rs. {Levels[i]}")

    if(i==4) :
      money = 1000
    elif(i==9):
      money = 320000
    elif(i==14) :
      money = 10000000
  else :
    print("\nWrong Answer!")
    break

print(f"\n🏁 Game Over! You take home Rs. {Money}")
print("\n🎉 Thank you for playing KAUN BANEGA CROREPATI! 🎉")
# Out:
# 💰💰💰  WELCOME TO KAUN BANEGA CROREPATI  💰💰💰
#
#
# Question for Rs. 1000:
# 1. What is the correct file extension for Python files?
# a. .pt
# b. .py
# c. .pyt
# d. .ptn
#
# Available Lifelines: ['50-50', 'Ask the Audience', 'Skip Question']
#
# Which lifeline do you want to use?
